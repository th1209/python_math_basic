# %% [markdown]
# #### pyplotの基本

# %%
# 以下では、pyplotで基本的なグラフを描画する。
# 2章で勉強したpylabと同じ要領でグラフを描画できる。
from matplotlib.pyplot import plot
from matplotlib.pyplot import show
from matplotlib.pyplot import title
from matplotlib.pyplot import xlabel
from matplotlib.pyplot import ylabel
from matplotlib.pyplot import legend
from matplotlib.pyplot import axis
from matplotlib.pyplot import savefig

# %%
# pylabと同じく、NYCの気温のグラフの描画例。
nyc_temp_2000 = [31.3, 37.3, 47.2, 51.0, 63.5, 71.3, 72.3, 72.7, 66.0, 57.0, 45.3, 31.1]
nyc_temp_2006 = [40.9, 35.7, 43.1, 55.7, 63.1, 71.0, 77.9, 75.8, 66.6, 56.2, 51.9, 43.6]
nyc_temp_2012 = [37.3, 40.9, 50.9, 55.8, 65.1, 71.0, 77.8, 76.8, 68.8, 58.0, 43.9, 41.5]
months = range(1, 13)

plot(months, nyc_temp_2000, months, nyc_temp_2006, months, nyc_temp_2012)

title('Average monthly temperature in NYC')
xlabel('Month')
ylabel('Temperature')
legend([2000, 2006, 2012])
axis(ymin=30, ymax=100)

# 以下を呼び出すと、グラフデータを保存できる。
savefig('NewYorkCityTemperature.png')

show()
